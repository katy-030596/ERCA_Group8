# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("data.txt",skiprows=3)

# %%
data
# Out:
# array([[ 1.958e+03, -3.700e-01,  4.410e+00, ...,  1.766e+01,  1.150e+01,
#          9.870e+00],
#        [ 1.959e+03, -9.100e-01,  5.860e+00, ...,  1.861e+01,  1.062e+01,
#          1.034e+01],
#        [ 1.960e+03,  3.000e-01,  3.280e+00, ...,  1.706e+01,  9.140e+00,
#          9.510e+00],
#        ...,
#        [ 2.021e+03,  8.500e-01,  6.450e+00, ...,  1.970e+01,  1.203e+01,
#          1.107e+01],
#        [ 2.022e+03,  3.100e+00,  5.300e+00, ...,  2.270e+01,  1.295e+01,
#          1.277e+01],
#        [ 2.023e+03,  1.850e+00,  5.250e+00, ...,  2.107e+01,  1.280e+01,
#          1.205e+01]])

# %%
plt.plot(data)
