# %% [markdown]
# # ERCA - Group 8

# %% [markdown]
# This notebook present the surface temperature evolution since 1980, compared to the average temperature over 20 years (1958-1977).
#
# Data are taken from Goddard Institute for Space Studies (GISS)
#
# Source: https://data.giss.nasa.gov/cgi-bin/gistemp/stdata_show_v4.cgi?id=FRM00007591&ds=14&dt=1
#
# For Embrum Station

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.txt", sep='\\s+', skiprows=2)

# %%
Tmean=np.average(df.metANN[:20])

# %%
plt.plot(df.YEAR[20:],df.metANN[20:]-Tmean)
plt.xlabel('Year')
plt.ylabel('Temperature (Celsius)')
plt.title('Surface temperature evolution at Embrun')
# Out:
# Text(0.5, 1.0, 'Surface temperature evolution at Embrun')

# %%
df
# Out:
#     YEAR   JAN   FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0   1958 -0.37  4.41  2.81   6.79  15.25  15.03  18.43  19.52  16.86  10.31
# 1   1959 -0.91  5.86  7.91   8.82  13.11  16.90  20.73  18.19  16.49  10.70
# 2   1960  0.30  3.28  5.99   9.29  14.64  17.39  16.96  16.84  13.58   8.45
# 3   1961 -0.20  4.79  8.41  10.81  12.04  16.82  17.82  19.00  18.52  11.27
# 4   1962  2.33  1.78  2.45   8.25  11.67  16.00  18.84  20.56  15.69  12.20
# ..   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...    ...
# 61  2019  0.56  6.11  8.31   9.91  12.31  20.71  22.26  22.31  18.01  13.41
# 62  2020  4.46  6.06  7.76  12.91  15.91  17.01  21.61  21.51  17.16  10.01
# 63  2021  0.85  6.45  7.25   9.00  11.55  19.35  20.20  19.55  17.55  11.50
# 64  2022  3.10  5.30  8.15  10.60  16.85  21.45  24.10  22.55  15.95  15.45
# 65  2023  1.85  5.25  8.35   9.70  14.25  19.15  22.15  21.90  18.55  14.30
#
#      NOV   DEC  D-J-F  M-A-M  J-J-A  S-O-N  metANN
# 0   7.32  1.65   2.02   8.28  17.66  11.50    9.87
# 1   4.66  1.98   2.20   9.95  18.61  10.62   10.34
# 2   5.40  1.13   1.85   9.97  17.06   9.14    9.51
# 3   5.96  3.41   1.91  10.42  17.88  11.92   10.53
# 4   3.74 -0.40   2.51   7.46  18.47  10.54    9.74
# ..   ...   ...    ...    ...    ...    ...     ...
# 61  6.46  4.96   3.41  10.18  21.76  12.63   11.99
# 62  8.66  2.50   5.16  12.19  20.04  11.94   12.34
# 63  7.05  2.30   3.27   9.27  19.70  12.03   11.07
# 64  7.45  3.60   3.57  11.87  22.70  12.95   12.77
# 65  5.55  3.85   3.57  10.77  21.07  12.80   12.05
#
# [66 rows x 18 columns]

# %%
fig= plt.figure(figsize=(15,10))

TmeanJAN=np.average(df.JAN[:20])
plt.subplot(231)
plt.plot(df.YEAR[20:],df.JAN[20:]-TmeanJAN)
plt.xlabel('Year')
plt.ylabel('Temperature (Celsius)')
plt.title('January')

TmeanFEB=np.average(df.FEB[:20])
plt.subplot(232)
plt.plot(df.YEAR[20:],df.FEB[20:]-TmeanFEB)
plt.xlabel('Year')
plt.ylabel('Temperature (Celsius)')
plt.title('Febuary')
# Out:
# Text(0.5, 1.0, 'Febuary')
